# %%
import logging

logger = logging.getLogger(__name__)
logging.basicConfig(
    format='%(asctime)s - %(levelname)-8s | %(name)-20s | %(message)s',
    level=logging.INFO
    )

# %%
import time

from static import TEAMS_UNDERSTAT, YEARS
from understat import get_soup

# %%
dfs = []
for year in YEARS:
    for team in TEAMS_UNDERSTAT:
        logger.info(f"Scraping data from Year {year} and Team {team}")
        
        df = get_soup(team=team, year=year)

        if df is None:
            logger.info(f"DATA NOT FOUND")
            continue
        
        df["Year"] = int(year)
        
        dfs.append(df)
        time.sleep(2.5)
# Out:
# 2024-08-19 18:51:20,675 - INFO     | __main__             | Scraping data from Year 2024 and Team Inter
# 2024-08-19 18:51:23,476 - INFO     | __main__             | Scraping data from Year 2024 and Team AC_Milan
# 2024-08-19 18:51:26,284 - INFO     | __main__             | Scraping data from Year 2024 and Team Juventus
# 2024-08-19 18:51:29,181 - INFO     | __main__             | Scraping data from Year 2024 and Team Atalanta
# 2024-08-19 18:51:31,973 - INFO     | __main__             | Scraping data from Year 2024 and Team Bologna
# 2024-08-19 18:51:34,884 - INFO     | __main__             | Scraping data from Year 2024 and Team Roma
# 2024-08-19 18:51:37,678 - INFO     | __main__             | Scraping data from Year 2024 and Team Lazio
# 2024-08-19 18:51:40,604 - INFO     | __main__             | Scraping data from Year 2024 and Team Fiorentina
# 2024-08-19 18:51:43,524 - INFO     | __main__             | Scraping data from Year 2024 and Team Napoli
# 2024-08-19 18:51:46,428 - INFO     | __main__             | Scraping data from Year 2024 and Team Torino
# 2024-08-19 18:51:50,166 - INFO     | __main__             | Scraping data from Year 2024 and Team Genoa
# 2024-08-19 18:51:53,053 - INFO     | __main__             | Scraping data from Year 2024 and Team Monza
# 2024-08-19 18:51:55,913 - INFO     | __main__             | Scraping data from Year 2024 and Team Verona
# 2024-08-19 18:51:59,059 - INFO     | __main__             | Scraping data from Year 2024 and Team Lecce
# 2024-08-19 18:52:01,872 - INFO     | __main__             | Scraping data from Year 2024 and Team Udinese
# 2024-08-19 18:52:04,789 - INFO     | __main__             | Scraping data from Year 2024 and Team Empoli
# 2024-08-19 18:52:07,658 - INFO     | __main__             | Scraping data from Year 2024 and Team Cagliari
# 2024-08-19 18:52:10,563 - INFO     | __main__             | Scraping data from Year 2024 and Team Sassuolo
# 2024-08-19 18:52:13,830 - INFO     | __main__             | Scraping data from Year 2024 and Team Parma_Calcio_1913
# 2024-08-19 18:52:16,681 - INFO     | __main__             | Scraping data from Year 2024 and Team Como
# 2024-08-19 18:52:19,500 - INFO     | __main__             | Scraping data from Year 2024 and Team Venezia
# 2024-08-19 18:52:22,381 - INFO     | __main__             | Scraping data from Year 2024 and Team Sassuolo
# 2024-08-19 18:52:25,298 - INFO     | __main__             | Scraping data from Year 2024 and Team Frosinone
# 2024-08-19 18:52:28,526 - INFO     | __main__             | Scraping data from Year 2024 and Team Salernitana
# 2024-08-19 18:52:31,805 - INFO     | __main__             | Scraping data from Year 2024 and Team Spezia
# 2024-08-19 18:52:35,399 - INFO     | __main__             | Scraping data from Year 2024 and Team Cremonese
# 2024-08-19 18:52:38,628 - INFO     | __main__             | Scraping data from Year 2024 and Team Sampdoria
# 2024-08-19 18:52:41,965 - INFO     | __main__             | Scraping data from Year 2024 and Team Crotone
# 2024-08-19 18:52:45,455 - INFO     | __main__             | Scraping data from Year 2024 and Team Benevento
# 2024-08-19 18:52:48,709 - INFO     | __main__             | Scraping data from Year 2024 and Team Brescia
# 2024-08-19 18:52:52,292 - INFO     | __main__             | Scraping data from Year 2024 and Team SPAL_2013
# 2024-08-19 18:52:55,490 - INFO     | __main__             | Scraping data from Year 2023 and Team Inter
# 2024-08-19 18:52:58,329 - INFO     | __main__             | Scraping data from Year 2023 and Team AC_Milan
# 2024-08-19 18:53:01,265 - INFO     | __main__             | Scraping data from Year 2023 and Team Juventus
# 2024-08-19 18:53:05,081 - INFO     | __main__             | Scraping data from Year 2023 and Team Atalanta
# 2024-08-19 18:53:08,467 - INFO     | __main__             | Scraping data from Year 2023 and Team Bologna
# 2024-08-19 18:53:11,709 - INFO     | __main__             | Scraping data from Year 2023 and Team Roma
# 2024-08-19 18:53:14,957 - INFO     | __main__             | Scraping data from Year 2023 and Team Lazio
# 2024-08-19 18:53:18,298 - INFO     | __main__             | Scraping data from Year 2023 and Team Fiorentina
# 2024-08-19 18:53:21,680 - INFO     | __main__             | Scraping data from Year 2023 and Team Napoli
# 2024-08-19 18:53:24,951 - INFO     | __main__             | Scraping data from Year 2023 and Team Torino
# 2024-08-19 18:53:28,409 - INFO     | __main__             | Scraping data from Year 2023 and Team Genoa
# 2024-08-19 18:53:31,863 - INFO     | __main__             | Scraping data from Year 2023 and Team Monza
# 2024-08-19 18:53:35,013 - INFO     | __main__             | Scraping data from Year 2023 and Team Verona
# 2024-08-19 18:53:38,365 - INFO     | __main__             | Scraping data from Year 2023 and Team Lecce
# 2024-08-19 18:53:41,716 - INFO     | __main__             | Scraping data from Year 2023 and Team Udinese
# 2024-08-19 18:53:44,554 - INFO     | __main__             | Scraping data from Year 2023 and Team Empoli
# 2024-08-19 18:53:47,728 - INFO     | __main__             | Scraping data from Year 2023 and Team Cagliari
# 2024-08-19 18:53:50,928 - INFO     | __main__             | Scraping data from Year 2023 and Team Sassuolo
# 2024-08-19 18:53:53,854 - INFO     | __main__             | Scraping data from Year 2023 and Team Parma_Calcio_1913
# 2024-08-19 18:53:56,648 - INFO     | __main__             | Scraping data from Year 2023 and Team Como
# 2024-08-19 18:53:59,456 - INFO     | __main__             | Scraping data from Year 2023 and Team Venezia
# 2024-08-19 18:54:02,268 - INFO     | __main__             | Scraping data from Year 2023 and Team Sassuolo
# 2024-08-19 18:54:05,115 - INFO     | __main__             | Scraping data from Year 2023 and Team Frosinone
# 2024-08-19 18:54:08,024 - INFO     | __main__             | Scraping data from Year 2023 and Team Salernitana
# 2024-08-19 18:54:10,872 - INFO     | __main__             | Scraping data from Year 2023 and Team Spezia
# 2024-08-19 18:54:13,707 - INFO     | __main__             | Scraping data from Year 2023 and Team Cremonese
# 2024-08-19 18:54:16,618 - INFO     | __main__             | Scraping data from Year 2023 and Team Sampdoria
# 2024-08-19 18:54:19,467 - INFO     | __main__             | Scraping data from Year 2023 and Team Crotone
# 2024-08-19 18:54:22,395 - INFO     | __main__             | Scraping data from Year 2023 and Team Benevento
# 2024-08-19 18:54:25,221 - INFO     | __main__             | Scraping data from Year 2023 and Team Brescia
# 2024-08-19 18:54:28,150 - INFO     | __main__             | Scraping data from Year 2023 and Team SPAL_2013
# 2024-08-19 18:54:31,061 - INFO     | __main__             | Scraping data from Year 2022 and Team Inter
# 2024-08-19 18:54:33,999 - INFO     | __main__             | Scraping data from Year 2022 and Team AC_Milan
# 2024-08-19 18:54:36,850 - INFO     | __main__             | Scraping data from Year 2022 and Team Juventus
# 2024-08-19 18:54:40,519 - INFO     | __main__             | Scraping data from Year 2022 and Team Atalanta
# 2024-08-19 18:54:43,913 - INFO     | __main__             | Scraping data from Year 2022 and Team Bologna
# 2024-08-19 18:54:47,181 - INFO     | __main__             | Scraping data from Year 2022 and Team Roma
# 2024-08-19 18:54:50,565 - INFO     | __main__             | Scraping data from Year 2022 and Team Lazio
# 2024-08-19 18:54:53,830 - INFO     | __main__             | Scraping data from Year 2022 and Team Fiorentina
# 2024-08-19 18:54:57,061 - INFO     | __main__             | Scraping data from Year 2022 and Team Napoli
# 2024-08-19 18:55:00,383 - INFO     | __main__             | Scraping data from Year 2022 and Team Torino
# 2024-08-19 18:55:03,780 - INFO     | __main__             | Scraping data from Year 2022 and Team Genoa
# 2024-08-19 18:55:06,584 - INFO     | __main__             | Scraping data from Year 2022 and Team Monza
# 2024-08-19 18:55:09,805 - INFO     | __main__             | Scraping data from Year 2022 and Team Verona
# 2024-08-19 18:55:13,080 - INFO     | __main__             | Scraping data from Year 2022 and Team Lecce
# 2024-08-19 18:55:16,247 - INFO     | __main__             | Scraping data from Year 2022 and Team Udinese
# 2024-08-19 18:55:19,543 - INFO     | __main__             | Scraping data from Year 2022 and Team Empoli
# 2024-08-19 18:55:22,806 - INFO     | __main__             | Scraping data from Year 2022 and Team Cagliari
# 2024-08-19 18:55:25,605 - INFO     | __main__             | Scraping data from Year 2022 and Team Sassuolo
# 2024-08-19 18:55:28,961 - INFO     | __main__             | Scraping data from Year 2022 and Team Parma_Calcio_1913
# 2024-08-19 18:55:31,754 - INFO     | __main__             | Scraping data from Year 2022 and Team Como
# 2024-08-19 18:55:34,562 - INFO     | __main__             | Scraping data from Year 2022 and Team Venezia
# 2024-08-19 18:55:37,378 - INFO     | __main__             | Scraping data from Year 2022 and Team Sassuolo
# 2024-08-19 18:55:40,205 - INFO     | __main__             | Scraping data from Year 2022 and Team Frosinone
# 2024-08-19 18:55:43,137 - INFO     | __main__             | Scraping data from Year 2022 and Team Salernitana
# 2024-08-19 18:55:46,358 - INFO     | __main__             | Scraping data from Year 2022 and Team Spezia
# 2024-08-19 18:55:49,328 - INFO     | __main__             | Scraping data from Year 2022 and Team Cremonese
# 2024-08-19 18:55:52,228 - INFO     | __main__             | Scraping data from Year 2022 and Team Sampdoria
# 2024-08-19 18:55:55,156 - INFO     | __main__             | Scraping data from Year 2022 and Team Crotone
# 2024-08-19 18:55:58,067 - INFO     | __main__             | Scraping data from Year 2022 and Team Benevento
# 2024-08-19 18:56:00,913 - INFO     | __main__             | Scraping data from Year 2022 and Team Brescia
# 2024-08-19 18:56:03,844 - INFO     | __main__             | Scraping data from Year 2022 and Team SPAL_2013
# 2024-08-19 18:56:06,769 - INFO     | __main__             | Scraping data from Year 2021 and Team Inter
# 2024-08-19 18:56:09,617 - INFO     | __main__             | Scraping data from Year 2021 and Team AC_Milan
# 2024-08-19 18:56:12,462 - INFO     | __main__             | Scraping data from Year 2021 and Team Juventus
# 2024-08-19 18:56:16,167 - INFO     | __main__             | Scraping data from Year 2021 and Team Atalanta
# 2024-08-19 18:56:19,554 - INFO     | __main__             | Scraping data from Year 2021 and Team Bologna
# 2024-08-19 18:56:22,858 - INFO     | __main__             | Scraping data from Year 2021 and Team Roma
# 2024-08-19 18:56:27,123 - INFO     | __main__             | Scraping data from Year 2021 and Team Lazio
# 2024-08-19 18:56:31,036 - INFO     | __main__             | Scraping data from Year 2021 and Team Fiorentina
# 2024-08-19 18:56:34,283 - INFO     | __main__             | Scraping data from Year 2021 and Team Napoli
# 2024-08-19 18:56:37,664 - INFO     | __main__             | Scraping data from Year 2021 and Team Torino
# 2024-08-19 18:56:40,952 - INFO     | __main__             | Scraping data from Year 2021 and Team Genoa
# 2024-08-19 18:56:44,312 - INFO     | __main__             | Scraping data from Year 2021 and Team Monza
# 2024-08-19 18:56:47,106 - INFO     | __main__             | Scraping data from Year 2021 and Team Verona
# 2024-08-19 18:56:50,450 - INFO     | __main__             | Scraping data from Year 2021 and Team Lecce
# 2024-08-19 18:56:53,356 - INFO     | __main__             | Scraping data from Year 2021 and Team Udinese
# 2024-08-19 18:56:56,704 - INFO     | __main__             | Scraping data from Year 2021 and Team Empoli
# 2024-08-19 18:57:00,127 - INFO     | __main__             | Scraping data from Year 2021 and Team Cagliari
# 2024-08-19 18:57:03,451 - INFO     | __main__             | Scraping data from Year 2021 and Team Sassuolo
# 2024-08-19 18:57:06,839 - INFO     | __main__             | Scraping data from Year 2021 and Team Parma_Calcio_1913
# 2024-08-19 18:57:09,629 - INFO     | __main__             | Scraping data from Year 2021 and Team Como
# 2024-08-19 18:57:12,426 - INFO     | __main__             | Scraping data from Year 2021 and Team Venezia
# 2024-08-19 18:57:15,734 - INFO     | __main__             | Scraping data from Year 2021 and Team Sassuolo
# 2024-08-19 18:57:18,657 - INFO     | __main__             | Scraping data from Year 2021 and Team Frosinone
# 2024-08-19 18:57:21,513 - INFO     | __main__             | Scraping data from Year 2021 and Team Salernitana
# 2024-08-19 18:57:24,845 - INFO     | __main__             | Scraping data from Year 2021 and Team Spezia
# 2024-08-19 18:57:28,113 - INFO     | __main__             | Scraping data from Year 2021 and Team Cremonese
# 2024-08-19 18:57:30,956 - INFO     | __main__             | Scraping data from Year 2021 and Team Sampdoria
# 2024-08-19 18:57:34,263 - INFO     | __main__             | Scraping data from Year 2021 and Team Crotone
# 2024-08-19 18:57:37,098 - INFO     | __main__             | Scraping data from Year 2021 and Team Benevento
# 2024-08-19 18:57:39,948 - INFO     | __main__             | Scraping data from Year 2021 and Team Brescia
# 2024-08-19 18:57:42,870 - INFO     | __main__             | Scraping data from Year 2021 and Team SPAL_2013
# 2024-08-19 18:57:45,802 - INFO     | __main__             | Scraping data from Year 2020 and Team Inter
# 2024-08-19 18:57:48,665 - INFO     | __main__             | Scraping data from Year 2020 and Team AC_Milan
# 2024-08-19 18:57:51,590 - INFO     | __main__             | Scraping data from Year 2020 and Team Juventus
# 2024-08-19 18:57:55,257 - INFO     | __main__             | Scraping data from Year 2020 and Team Atalanta
# 2024-08-19 18:57:58,661 - INFO     | __main__             | Scraping data from Year 2020 and Team Bologna
# 2024-08-19 18:58:01,970 - INFO     | __main__             | Scraping data from Year 2020 and Team Roma
# 2024-08-19 18:58:05,297 - INFO     | __main__             | Scraping data from Year 2020 and Team Lazio
# 2024-08-19 18:58:08,654 - INFO     | __main__             | Scraping data from Year 2020 and Team Fiorentina
# 2024-08-19 18:58:12,064 - INFO     | __main__             | Scraping data from Year 2020 and Team Napoli
# 2024-08-19 18:58:15,335 - INFO     | __main__             | Scraping data from Year 2020 and Team Torino
# 2024-08-19 18:58:18,579 - INFO     | __main__             | Scraping data from Year 2020 and Team Genoa
# 2024-08-19 18:58:21,890 - INFO     | __main__             | Scraping data from Year 2020 and Team Monza
# 2024-08-19 18:58:24,740 - INFO     | __main__             | Scraping data from Year 2020 and Team Verona
# 2024-08-19 18:58:28,035 - INFO     | __main__             | Scraping data from Year 2020 and Team Lecce
# 2024-08-19 18:58:30,834 - INFO     | __main__             | Scraping data from Year 2020 and Team Udinese
# 2024-08-19 18:58:34,154 - INFO     | __main__             | Scraping data from Year 2020 and Team Empoli
# 2024-08-19 18:58:36,968 - INFO     | __main__             | Scraping data from Year 2020 and Team Cagliari
# 2024-08-19 18:58:40,305 - INFO     | __main__             | Scraping data from Year 2020 and Team Sassuolo
# 2024-08-19 18:58:43,614 - INFO     | __main__             | Scraping data from Year 2020 and Team Parma_Calcio_1913
# 2024-08-19 18:58:46,873 - INFO     | __main__             | Scraping data from Year 2020 and Team Como
# 2024-08-19 18:58:49,688 - INFO     | __main__             | Scraping data from Year 2020 and Team Venezia
# 2024-08-19 18:58:52,493 - INFO     | __main__             | Scraping data from Year 2020 and Team Sassuolo
# 2024-08-19 18:58:55,400 - INFO     | __main__             | Scraping data from Year 2020 and Team Frosinone
# 2024-08-19 18:58:58,251 - INFO     | __main__             | Scraping data from Year 2020 and Team Salernitana
# 2024-08-19 18:59:01,160 - INFO     | __main__             | Scraping data from Year 2020 and Team Spezia
# 2024-08-19 18:59:04,448 - INFO     | __main__             | Scraping data from Year 2020 and Team Cremonese
# 2024-08-19 18:59:07,344 - INFO     | __main__             | Scraping data from Year 2020 and Team Sampdoria
# 2024-08-19 18:59:10,726 - INFO     | __main__             | Scraping data from Year 2020 and Team Crotone
# 2024-08-19 18:59:13,658 - INFO     | __main__             | Scraping data from Year 2020 and Team Benevento
# 2024-08-19 18:59:16,488 - INFO     | __main__             | Scraping data from Year 2020 and Team Brescia
# 2024-08-19 18:59:19,346 - INFO     | __main__             | Scraping data from Year 2020 and Team SPAL_2013
# 2024-08-19 18:59:22,271 - INFO     | __main__             | Scraping data from Year 2019 and Team Inter
# 2024-08-19 18:59:25,270 - INFO     | __main__             | Scraping data from Year 2019 and Team AC_Milan
# 2024-08-19 18:59:28,151 - INFO     | __main__             | Scraping data from Year 2019 and Team Juventus
# 2024-08-19 18:59:31,950 - INFO     | __main__             | Scraping data from Year 2019 and Team Atalanta
# 2024-08-19 18:59:35,332 - INFO     | __main__             | Scraping data from Year 2019 and Team Bologna
# 2024-08-19 18:59:38,690 - INFO     | __main__             | Scraping data from Year 2019 and Team Roma
# 2024-08-19 18:59:41,978 - INFO     | __main__             | Scraping data from Year 2019 and Team Lazio
# 2024-08-19 18:59:45,350 - INFO     | __main__             | Scraping data from Year 2019 and Team Fiorentina
# 2024-08-19 18:59:48,727 - INFO     | __main__             | Scraping data from Year 2019 and Team Napoli
# 2024-08-19 18:59:52,100 - INFO     | __main__             | Scraping data from Year 2019 and Team Torino
# 2024-08-19 18:59:55,366 - INFO     | __main__             | Scraping data from Year 2019 and Team Genoa
# 2024-08-19 18:59:58,667 - INFO     | __main__             | Scraping data from Year 2019 and Team Monza
# 2024-08-19 19:00:01,477 - INFO     | __main__             | Scraping data from Year 2019 and Team Verona
# 2024-08-19 19:00:05,005 - INFO     | __main__             | Scraping data from Year 2019 and Team Lecce
# 2024-08-19 19:00:08,395 - INFO     | __main__             | Scraping data from Year 2019 and Team Udinese
# 2024-08-19 19:00:11,880 - INFO     | __main__             | Scraping data from Year 2019 and Team Empoli
# 2024-08-19 19:00:14,745 - INFO     | __main__             | Scraping data from Year 2019 and Team Cagliari
# 2024-08-19 19:00:17,989 - INFO     | __main__             | Scraping data from Year 2019 and Team Sassuolo
# 2024-08-19 19:00:21,302 - INFO     | __main__             | Scraping data from Year 2019 and Team Parma_Calcio_1913
# 2024-08-19 19:00:24,600 - INFO     | __main__             | Scraping data from Year 2019 and Team Como
# 2024-08-19 19:00:27,404 - INFO     | __main__             | Scraping data from Year 2019 and Team Venezia
# 2024-08-19 19:00:30,231 - INFO     | __main__             | Scraping data from Year 2019 and Team Sassuolo
# 2024-08-19 19:00:33,365 - INFO     | __main__             | Scraping data from Year 2019 and Team Frosinone
# 2024-08-19 19:00:36,216 - INFO     | __main__             | Scraping data from Year 2019 and Team Salernitana
# 2024-08-19 19:00:39,187 - INFO     | __main__             | Scraping data from Year 2019 and Team Spezia
# 2024-08-19 19:00:42,055 - INFO     | __main__             | Scraping data from Year 2019 and Team Cremonese
# 2024-08-19 19:00:45,011 - INFO     | __main__             | Scraping data from Year 2019 and Team Sampdoria
# 2024-08-19 19:00:48,929 - INFO     | __main__             | Scraping data from Year 2019 and Team Crotone
# 2024-08-19 19:00:51,835 - INFO     | __main__             | Scraping data from Year 2019 and Team Benevento
# 2024-08-19 19:00:54,707 - INFO     | __main__             | Scraping data from Year 2019 and Team Brescia
# 2024-08-19 19:00:57,645 - INFO     | __main__             | Scraping data from Year 2019 and Team SPAL_2013

# %%
import pandas as pd

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df.to_csv("../db/raw/understat.csv", index=False)

# %%
def extract_last_name(full_name):
    name_parts = full_name.split()
    if len(name_parts) > 2:
        return ' '.join(name_parts[-2:])  # Last two parts are the last name
    else:
        return name_parts[-1]  # Last part is the last name

# %%
understat = pd.read_csv("../db/raw/understat.csv").query("Year == 2023")
fleghe = pd.read_csv("../db/clean/stats.csv").query("Year == 2024")

# %%
understat['last_name'] = understat['player_name'].apply(extract_last_name)
understat['first_initial'] = understat['player_name'].apply(lambda x: x.split()[0][0])

# Step 2: Identify duplicates
duplicate_last_names = understat['last_name'].duplicated(keep=False)

# Step 3: Append the first initial to duplicates only
understat.loc[duplicate_last_names, 'merge_key'] = understat['last_name'] + ' ' + understat['first_initial'] + '.'
understat.loc[~duplicate_last_names, 'merge_key'] = understat['last_name']

# %%
understat.drop(columns=['id', 'Year', 'player_name'], inplace=True)

# %%
understat.head()
# Out:
#      games  time  goals         xG  assists        xA  shots  key_passes  \
# 614     33  2688     24  19.917104        3  4.228376    109          36
# 615     32  2618     13   9.977345        3  4.402720     62          51
# 616     35  2750     13  15.489109        7  4.381468     77          30
# 617     32   877      6   8.650839        3  2.203673     32          10
# 618     27   748      5   5.603071        3  2.895867     17          16
#
#      yellow_cards  red_cards position team_title  npg       npxG    xGChain  \
# 614             5          0      F S      Inter   22  17.633207  29.067482
# 615             5          0        M      Inter    3   2.364357  21.514876
# 616             3          0      F S      Inter   13  15.489109  25.697543
# 617             1          0      M S      Inter    6   8.650839  12.410261
# 618             0          0      F S      Inter    5   5.603071   9.664403
#
#      xGBuildup   last_name first_initial    merge_key
# 614  11.011354    Martínez             L  Martínez L.
# 615  18.073472  Calhanoglu             H   Calhanoglu
# 616   8.535634      Thuram             M       Thuram
# 617   3.090515    Frattesi             D     Frattesi
# 618   2.593221  Arnautovic             M   Arnautovic

# %%
merged_df = pd.merge(fleghe, understat, left_on='Name', right_on='merge_key', how='left')

# %%
merged_df.to_csv("../db/clean/stats_merged.csv", index=False)

# %%
merged_df.columns
# Out:
# Index(['Id', 'R', 'Name', 'Team', 'Year', 'Pv', 'Mv', 'Fm', 'games', 'time',
#        'goals', 'xG', 'assists', 'xA', 'shots', 'key_passes', 'yellow_cards',
#        'red_cards', 'position', 'team_title', 'npg', 'npxG', 'xGChain',
#        'xGBuildup', 'last_name', 'first_initial', 'merge_key'],
#       dtype='object')
