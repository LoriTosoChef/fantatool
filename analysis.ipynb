# %%
import pandas as pd

# %%
fleghe = pd.read_csv("./db/clean/stats.csv")
understat = pd.read_csv("./db/raw/understat.csv")
full = pd.read_csv("./db/clean/stats_merged.csv")

full.drop(columns=['team_title', 'first_initial', 'merge_key', 'Pv', 'Year', 'Mv', 'Fm'], inplace=True)

# %%
fleghe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3899 entries, 0 to 3898
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      3899 non-null   int64
#  1   R       3899 non-null   object
#  2   Name    3899 non-null   object
#  3   Team    3899 non-null   object
#  4   Year    3899 non-null   int64
#  5   Pv      3899 non-null   int64
#  6   Mv      3899 non-null   float64
#  7   Fm      3899 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 243.8+ KB

# %%
understat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5006 entries, 0 to 5005
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            5006 non-null   int64
#  1   player_name   5006 non-null   object
#  2   games         5006 non-null   int64
#  3   time          5006 non-null   int64
#  4   goals         5006 non-null   int64
#  5   xG            5006 non-null   float64
#  6   assists       5006 non-null   int64
#  7   xA            5006 non-null   float64
#  8   shots         5006 non-null   int64
#  9   key_passes    5006 non-null   int64
#  10  yellow_cards  5006 non-null   int64
#  11  red_cards     5006 non-null   int64
#  12  position      5006 non-null   object
#  13  team_title    5006 non-null   object
#  14  npg           5006 non-null   int64
#  15  npxG          5006 non-null   float64
#  16  xGChain       5006 non-null   float64
#  17  xGBuildup     5006 non-null   float64
# ...

# %%
full
# Out:
#        Id  R         Name      Team  games    time  goals   xG  assists  \
# 0    2428  P       Sommer     Inter   34.0  3060.0    0.0  0.0      0.0
# 1    5876  P  Di Gregorio  Juventus   33.0  2872.0    0.0  0.0      0.0
# 2     572  P        Meret    Napoli   31.0  2774.0    0.0  0.0      0.0
# 3    4312  P      Maignan     Milan   29.0  2610.0    0.0  0.0      1.0
# 4    4431  P  Carnesecchi  Atalanta    NaN     NaN    NaN  NaN      NaN
# ..    ... ..          ...       ...    ...     ...    ...  ...      ...
# 524  6603  A   Joao Costa      Roma    NaN     NaN    NaN  NaN      NaN
# 525  6648  A        Jasim      Como    NaN     NaN    NaN  NaN      NaN
# 526  6658  A   Gioacchini      Como    NaN     NaN    NaN  NaN      NaN
# 527  6670  A  Charpentier     Parma    NaN     NaN    NaN  NaN      NaN
# 528  6822  A      Ekhator     Genoa    NaN     NaN    NaN  NaN      NaN
#
#            xA  shots  key_passes  yellow_cards  red_cards position  npg  npxG  \
# ...

# %%
fleghe.head()
# Out:
#      Id  R         Name      Team  Year  Pv   Mv   Fm
# 0  2428  P       Sommer     Inter  2024   1  5.5  6.5
# 1  5876  P  Di Gregorio  Juventus  2024   0  0.0  0.0
# 2   572  P        Meret    Napoli  2024   1  6.0  3.0
# 3  4312  P      Maignan     Milan  2024   1  7.0  5.0
# 4  4431  P  Carnesecchi  Atalanta  2024   0  0.0  0.0

# %%
understat.head()
# Out:
#      id         player_name  games  time  goals        xG  assists       xA  \
# 0  5992       Marcus Thuram      1    90      2  0.802502        0  0.17083
# 1   189    Hakan Calhanoglu      1    78      0  0.019773        0  0.00000
# 2   199         Yann Sommer      1    90      0  0.000000        0  0.00000
# 3   317  Henrikh Mkhitaryan      1    69      0  0.054838        0  0.00000
# 4   557      Matteo Darmian      1    69      0  0.000000        0  0.00000
#
#    shots  key_passes  yellow_cards  red_cards position team_title  npg  \
# 0      5           2             0          0        F      Inter    2
# 1      1           0             0          0        M      Inter    0
# 2      0           0             0          0       GK      Inter    0
# 3      1           0             1          0        M      Inter    0
# 4      0           0             0          0        D      Inter    0
#
#        npxG   xGChain  xGBuildup  Year
# 0  0.802502  0.953104   0.150602  2024
# ...

# %%
full.head()
# Out:
#      Id  R         Name      Team  games    time  goals   xG  assists  \
# 0  2428  P       Sommer     Inter   34.0  3060.0    0.0  0.0      0.0
# 1  5876  P  Di Gregorio  Juventus   33.0  2872.0    0.0  0.0      0.0
# 2   572  P        Meret    Napoli   31.0  2774.0    0.0  0.0      0.0
# 3  4312  P      Maignan     Milan   29.0  2610.0    0.0  0.0      1.0
# 4  4431  P  Carnesecchi  Atalanta    NaN     NaN    NaN  NaN      NaN
#
#          xA  shots  key_passes  yellow_cards  red_cards position  npg  npxG  \
# 0  0.000000    0.0         0.0           1.0        0.0       GK  0.0   0.0
# 1  0.000000    0.0         0.0           0.0        0.0       GK  0.0   0.0
# 2  0.184997    0.0         1.0           0.0        0.0       GK  0.0   0.0
# 3  0.187058    0.0         3.0           1.0        1.0       GK  0.0   0.0
# 4       NaN    NaN         NaN           NaN        NaN      NaN  NaN   NaN
#
#     xGChain  xGBuildup    last_name
# 0  9.555545   9.555545       Sommer
# ...

# %%
full['delta_xG'] = full['goals'] - full['xG']
full.sort_values('delta_xG', ascending=False).head(50)
# Out:
#        Id  R          Name        Team  games    time  goals         xG  \
# 256  5685  C   Koopmeiners    Atalanta   34.0  2641.0   12.0   6.477180
# 255  2423  C       Pulisic       Milan   36.0  2658.0   12.0   8.112776
# 433  2137  A      Scamacca    Atalanta   29.0  1445.0   12.0   8.273880
# 257  2194  C    Calhanoglu       Inter   32.0  2618.0   13.0   9.977345
# 260  5878  C       Colpani  Fiorentina   38.0  2751.0    8.0   5.195591
# 314  1976  C    Mazzitelli        Como   29.0  2229.0    5.0   2.270628
# 443  5995  A  De Ketelaere    Atalanta   35.0  2064.0   10.0   7.576864
# 429   309  A        Dybala        Roma   28.0  2011.0   13.0  10.748246
# 269  5119  C     Samardzic    Atalanta   34.0  2393.0    6.0   3.764858
# 265  4199  C  Loftus-Cheek       Milan   29.0  2111.0    6.0   3.988020
# 367  4947  C   Brescianini    Atalanta   36.0  2324.0    4.0   2.032999
# 202   487  D  De Silvestri     Bologna   15.0   668.0    2.0   0.201005
# ...
